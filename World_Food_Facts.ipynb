# %% [markdown]
# <a href="https://colab.research.google.com/github/SwapnilSParkhe/Pandas-Exercises/blob/main/World_Food_Facts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Getting and knowing the data ([Exercise](https://github.com/guipsamora/pandas_exercises/blob/master/01_Getting_%26_Knowing_Your_Data/World%20Food%20Facts/Exercises.ipynb))**

# %% [markdown]
# **1. Calibrating Colab/Kaggle interface**
# ([Resource](https://medium.com/@saedhussain/google-colaboratory-and-kaggle-datasets-b57a83eb6ef8))
#
# **a.  Kaggle API token, a JSON file**
# *   Go to your Kaggle account
# *   Download the JSON file for your API token
# *   Upload the API token file
#
# **b.  Kaggle and working directory**
# *   Install the Kaggle library
# *   Create the ~/.kaggle folder using mkdir (as the Kaggle API expects the JSON file to be there)
# *   Copy the JSON file to that folder using cp
# *   Give read, write access to owner using chmod 600
#
# **c.  Data download**
# *    Go to Kaggle's data page you are interested in ([World Food Facts](https://www.kaggle.com/openfoodfacts/world-food-facts))
# *   Copy the API link and paste it here to download the data

# %%
# Uploading the file (my Kaggle API token JSON file that I downloaded from my Kaggle account) here
from google.colab import files
my_kaggle_API = files.upload()
# Out:
#      <input type="file" id="files-6100ff2c-943c-4536-8f1b-8f61f16c8dbb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6100ff2c-943c-4536-8f1b-8f61f16c8dbb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# Installing Kaggle library
# !pip install kaggle

# %%
# Making the ~/.kaggle directory
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Downloading the data using the API link
# !kaggle datasets download -d openfoodfacts/world-food-facts
# Out:
# world-food-facts.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# Checking the directory's contents
# !ls
# Out:
# kaggle.json  sample_data  world-food-facts.zip

# %% [markdown]
# **2. Getting the data**

# %%
# Unzipping and assigning it to 'food'
import pandas as pd
food = pd.read_csv('world-food-facts.zip', compression='zip',  sep='\t' )
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# **3. Knowing the data**

# %%
# Top 5 entries?
pd.set_option('display.max_columns', None)
food.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %%
# No. of rows and columns (rows, cols)?
food.shape
# Out:
# (356027, 163)

# %%
# Print all columns?
food.columns.to_list()
# Out:
# ['code',
#  'url',
#  'creator',
#  'created_t',
#  'created_datetime',
#  'last_modified_t',
#  'last_modified_datetime',
#  'product_name',
#  'generic_name',
#  'quantity',
#  'packaging',
#  'packaging_tags',
#  'brands',
#  'brands_tags',
#  'categories',
#  'categories_tags',
#  'categories_en',
#  'origins',
#  'origins_tags',
#  'manufacturing_places',
#  'manufacturing_places_tags',
#  'labels',
#  'labels_tags',
#  'labels_en',
#  'emb_codes',
#  'emb_codes_tags',
#  'first_packaging_code_geo',
#  'cities',
#  'cities_tags',
#  'purchase_places',
#  'stores',
#  'countries',
#  'countries_tags',
#  'countries_en',
#  'ingredients_text',
#  'allergens',
#  'allergens_en',
#  'traces',
#  'traces_tags',
#  'traces_en',
#  'serving_size',
#  'no_nutriments',
#  'additives_n',
#  'additives',
#  'additives_tags',
#  'additives_en',
#  'ingredients_from_palm_oil_n',
#  'ingredients_from_palm_oil',
#  'ingredients_from_palm_oil_tags',
# ...

# %%
# Name of ith column?
i=105
food.columns[i-1]
# Out:
# '-glucose_100g'

# %%
# Type of observations for ith column?
food.dtypes[i-1]
# Out:
# dtype('float64')

# %%
# How is the dataset indexed?
food.index
# Out:
# RangeIndex(start=0, stop=356027, step=1)

# %%
# Product_name of the jth observation?
j=19
food.iloc[j-1,:]['product_name']
# Out:
# 'Lotus Organic Brown Jasmine Rice'

# %%
# Extra: High level statistics for numeric and categorical variables
pd.set_option('display.max_rows', None)
food.describe(include='all').transpose()
# Out:
#                                              count  ...          max
# code                                        356001  ...          NaN
# url                                         356001  ...          NaN
# creator                                     356024  ...          NaN
# created_t                                   356024  ...          NaN
# created_datetime                            356017  ...          NaN
# last_modified_t                             356027  ...          NaN
# last_modified_datetime                      356027  ...          NaN
# product_name                                338515  ...          NaN
# generic_name                                 57714  ...          NaN
# quantity                                    119285  ...          NaN
# packaging                                    89959  ...          NaN
# packaging_tags                               89959  ...          NaN
# brands                                      326977  ...          NaN
# ...
